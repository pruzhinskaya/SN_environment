# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np 
from math import *
from astropy.io import fits
import glob
import pylab 
from numpy.linalg import inv
import pandas

filename = 'data/z08.csv'
SNdata = pandas.read_csv(filename, header=0, delimiter=r",")

# %%
j = 0
for i in SNdata.index:
#     if SNdata['gMeanPSFMag'][i] != -999.000000 and SNdata['rMeanPSFMag'][i] != -999.000000:
    if SNdata['gMeanPSFMag'][i] != -999.000000 and SNdata['rMeanPSFMag'][i] != -999.000000 and SNdata['iMeanPSFMag'][i] != -999.000000:
#     if SNdata['gMeanPSFMag'][i] != -999.000000 and SNdata['rMeanPSFMag'][i] != -999.000000 and SNdata['iMeanPSFMag'][i] != -999.000000 and SNdata['zMeanPSFMag'][i] != -999.000000:
#     if SNdata['gMeanPSFMag'][i] != -999.000000 and SNdata['rMeanPSFMag'][i] != -999.000000 and SNdata['iMeanPSFMag'][i] != -999.000000 and SNdata['zMeanPSFMag'][i] != -999.000000 and SNdata['yMeanPSFMag'][i] != -999.000000:

        j += 1
print(j)
# Out:
# 36

# %%
SNdata
# Out:
#              ra        dec           searchString  \
# 0    131.068924  45.344208   131.068924 45.344208
# 1    131.068924  45.344208   131.068924 45.344208
# 2    334.083984 -18.042557  334.083984 -18.042557
# 3    334.083984 -18.042557  334.083984 -18.042557
# 4    161.079681  58.076195   161.079681 58.076195
# 5    161.079681  58.076195   161.079681 58.076195
# 6    333.607697 -17.671110  333.607697 -17.671110
# 7    333.607697 -17.671110  333.607697 -17.671110
# 8    333.607697 -17.671110  333.607697 -17.671110
# 9    333.607697 -17.671110  333.607697 -17.671110
# 10    36.287354  -3.353392    36.287354 -3.353392
# 11   212.879410  53.579578   212.879410 53.579578
# 12   212.879410  53.579578   212.879410 53.579578
# 13   214.699173  52.756557   214.699173 52.756557
# 14   214.699173  52.756557   214.699173 52.756557
# 15   149.867172   2.321014    149.867172 2.321014
# 16   149.867172   2.321014    149.867172 2.321014
# 17   149.867172   2.321014    149.867172 2.321014
# ...
